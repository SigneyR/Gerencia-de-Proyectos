# %% [markdown]
# <a href="https://colab.research.google.com/github/SigneyR/Gerencia-de-Proyectos/blob/main/Sesion2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Paso 1 — Establecer la Mentalidad (Mindset)
# La nueva edición consolida los principios de gestión de 12 a 6 principios refinados, enfocados en liderazgo responsable y cultura empoderada. Se basa en tres dimensiones clave: proactividad, propiedad (accountability) y orientación al valor estratégico. Está fundamentada en evidencia global, con aportes de expertos de 10 países en 5 continentes.
#
# Paso 2 — Operacionalizar la Mecánica (Dominios de Desempeño)
# Integra 8 dominios de desempeño (gobernanza, alcance, cronograma, finanzas, interesados, recursos, riesgo, medición) que funcionan como un sistema unificado para la entrega de valor. Se pasa del proceso tradicional (iniciación → planificación → ejecución → monitoreo → cierre) a áreas de enfoque adaptables a metodologías ágiles, predictivas o híbridas. Todo esto se enmarca en un sistema de entrega de valor que conecta visión, estrategia, cartera, programas/proyectos y operaciones.
#
# Paso 3 — Tutorial Técnico de Gestión Financiera
# Cubre la diferencia entre CapEx (gastos de capital, activos fijos) y OpEx (costos operativos diarios), especialmente relevante en infraestructura cloud. Introduce métricas de viabilidad financiera (ROI, VAN, TIR) que deben evaluarse antes de invertir, y las métricas clave del Valor Ganado (EVM): Valor Planificado (PV), Costo Real (AC), Valor Ganado (EV), Índice de Desempeño del Costo (CPI) y Variación del Cronograma (SV).
#
# Paso 4 — Sastrería (Tailoring) y Cierre
# Propone un proceso de 4 pasos para adaptar el enfoque de gestión: seleccionar el enfoque inicial, adaptarlo a la organización, al proyecto (tamaño/criticidad) e implementar mejora continua. La elección entre enfoque predictivo (cascada) o adaptativo (ágil) depende de factores como cultura organizacional, experiencia del equipo y acceso al cliente. Finalmente, destaca la importancia del cierre formal y la captura de lecciones aprendidas para nutrir la base de conocimiento organizacional.
